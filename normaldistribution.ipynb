# %% [markdown]
# <a href="https://colab.research.google.com/github/siddh-webd-ml/Machine-Learning/blob/main/normaldistribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/BEML_lyst1729240526796.csv")

# %%
df
# Out:
#             Date     Open     High      Low     Last    Close  \
# 0     2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60
# 1     2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60
# 2     2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60
# 3     2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15
# 4     2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05
# ...          ...      ...      ...      ...      ...      ...
# 1734  2016-12-26   965.00   965.05   935.00   950.10   950.25
# 1735  2016-12-27   960.70   989.00   952.35   974.00   975.70
# 1736  2016-12-28   980.75   985.00   970.15   977.00   974.40
# 1737  2016-12-29   977.10   997.95   974.55   985.15   986.05
# 1738  2016-12-30   986.00  1006.95   985.90  1004.00  1000.60
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                 101651.0          1157.18
# 1                  59504.0           676.47
# 2                 128908.0          1482.84
# ...

# %%
df[["Date","Close"]]
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
df=df.set_index(pd.DatetimeIndex(df["Date"]))

# %%
df = df.drop("Date",axis=1)

# %%
df
# Out:
#                Open     High      Low     Last    Close  Total Trade Quantity  \
# Date
# 2010-01-04  1121.00  1151.00  1121.00  1134.00  1135.60              101651.0
# 2010-01-05  1146.80  1149.00  1128.75  1135.00  1134.60               59504.0
# 2010-01-06  1140.00  1164.25  1130.05  1137.00  1139.60              128908.0
# 2010-01-07  1142.00  1159.40  1119.20  1141.00  1144.15              117871.0
# 2010-01-08  1156.00  1172.00  1140.00  1141.20  1144.05              170063.0
# ...             ...      ...      ...      ...      ...                   ...
# 2016-12-26   965.00   965.05   935.00   950.10   950.25              398696.0
# 2016-12-27   960.70   989.00   952.35   974.00   975.70              808561.0
# 2016-12-28   980.75   985.00   970.15   977.00   974.40              367041.0
# 2016-12-29   977.10   997.95   974.55   985.15   986.05              555233.0
# 2016-12-30   986.00  1006.95   985.90  1004.00  1000.60              460675.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.plot(df["Close"])

# %%
df["gain"] = df["Close"].pct_change(periods=1)

# %%
df["gain"]
# Out:
# Date
# 2010-01-04         NaN
# 2010-01-05   -0.000881
# 2010-01-06    0.004407
# 2010-01-07    0.003993
# 2010-01-08   -0.000087
#                 ...
# 2016-12-26   -0.021924
# 2016-12-27    0.026782
# 2016-12-28   -0.001332
# 2016-12-29    0.011956
# 2016-12-30    0.014756
# Name: gain, Length: 1739, dtype: float64

# %%
sns.distplot(df["gain"])
# Out:
# <ipython-input-14-e03e878c80b3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["gain"])
# <Axes: xlabel='gain', ylabel='Density'>

# %%
df["gain"].describe()
# Out:
# count    1738.000000
# mean        0.000271
# std         0.026431
# min        -0.133940
# 25%        -0.013736
# 50%        -0.001541
# 75%         0.011985
# max         0.198329
# Name: gain, dtype: float64

# %%
from scipy import stats

# %%
beml_gain_ci = stats.norm.interval(0.95,loc=df["gain"].mean(),scale=df["gain"].std())

# %%
sns.distplot(df["gain"])
# Out:
# <ipython-input-20-e03e878c80b3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["gain"])
# <Axes: xlabel='gain', ylabel='Density'>
